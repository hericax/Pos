# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_covtype

# %%
covtype = fetch_covtype()
# Out:
# ...
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-437f7e0de642> in <module>
# ----> 1 covtype = fetch_covtype()
#
# ~\anaconda\envs\pos-ds-ia-3.7\lib\site-packages\sklearn\datasets\covtype.py in fetch_covtype(data_home, download_if_missing, random_state, shuffle, return_X_y)
#     111
#     112         archive_path = _fetch_remote(ARCHIVE, dirname=covtype_dir)
# --> 113         Xy = np.genfromtxt(GzipFile(filename=archive_path), delimiter=',')
#     114         # delete archive
#     115         remove(archive_path)
#
# ~\anaconda\envs\pos-ds-ia-3.7\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
# ...

# %%
fig, ax = plt.subplots(1,1)
ax.imshow(covtype.data[0].reshape(6, 9), cmap='gray')
ax.set_xlabel(covtype.target[0])
plt.show()
