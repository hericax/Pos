# %% [markdown]
# <a href="https://colab.research.google.com/github/hericax/Pos/blob/master/Aula_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 19
#
# - House Prices: Advanced Regression Techniques: https://www.kaggle.com/c/house-prices-advanced-regression-techniques
#
# - Meta-Learning

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks/'
# Out:
# 'Aula #13.ipynb'  'Pré-processamento de dados - Exercício.ipynb'   train.csv
# 'Aula #15.ipynb'   test.csv

# %%
dataset = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/train.csv')
dataset.head(5)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
print(dataset.shape)
# Out:
# (1460, 81)

# %%
# descricao estatistica dos dados
dataset.describe().T #use T para transpor a matriz

# %%
#obtem algumas informacoes sobre as features
dataset.info()

# %%
pd.options.display.max_rows = 4000
print(dataset.dtypes)
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
def missing_percentage(df):
    """
    Essa funcao recebe um DataFrame de entrada e retorna duas colunas:
    - total de valores faltantes
    - percentual de valores faltantes
    """
    total = df.isnull().sum().sort_values(ascending = False)[df.isnull().sum().sort_values(ascending = False) != 0]
    percent = round(df.isnull().sum().sort_values(ascending = False)/len(df)*100,2)[round(df.isnull().sum().sort_values(ascending = False)/len(df)*100,2) != 0]
    return pd.concat([total, percent], axis=1, keys=['Total','Percent'])

# %%
missing_percentage(dataset)
# Out:
#               Total  Percent
# PoolQC         1453    99.52
# MiscFeature    1406    96.30
# Alley          1369    93.77
# Fence          1179    80.75
# FireplaceQu     690    47.26
# LotFrontage     259    17.74
# GarageCond       81     5.55
# GarageType       81     5.55
# GarageYrBlt      81     5.55
# GarageFinish     81     5.55
# GarageQual       81     5.55
# BsmtExposure     38     2.60
# BsmtFinType2     38     2.60
# BsmtFinType1     37     2.53
# BsmtCond         37     2.53
# BsmtQual         37     2.53
# MasVnrArea        8     0.55
# MasVnrType        8     0.55
# Electrical        1     0.07

# %%
dataset_test = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/test.csv')
dataset_test.head(5)
