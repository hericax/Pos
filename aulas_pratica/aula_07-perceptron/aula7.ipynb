# %%
import pandas as pd
import numpy as np

# %%
class Perceptron(object):

    def __init__(self, taxa_aprendizado, n_features, pesos=None, epocas=100):
      self.taxa_aprendizado = taxa_aprendizado
      if pesos is None:
        self.pesos = np.random.uniform(-1, 1, n_features)
      self.epocas = epocas

    # x_train é um DataFrame com as features do conjunto de dados
    # y_train é um Series com os rótulos (label) do conjunto de dados
    def fit(self, x_train, y_train):

      for e in range(self.epocas):

        print("---------------------------")
        print("Epoca:", e)

        qtde_erros = 0

        n_linhas = x_train.shape[0]
        for n in range(n_linhas):
          
          print("\t---------------------------")
          print("\tAmostra:", n)

          np_x = x_train.iloc[n].values
          np_y = y_train.iloc[n]

          print("\tx_atual:", np_x)
          print("\tpesos:", self.pesos)

          output = np.dot(self.pesos, np_x)
          print("\toutput:", output)

          heaveside = 1 if output >= 0 else 0
          print("\theaveside:", heaveside)

          # houve erro
          if heaveside != np_y:

            qtde_erros += 1
            erro = np_y - heaveside
            print("\terro:", erro)
            
            self.pesos = self.pesos + (self.taxa_aprendizado * erro * np_x)
            print("\tpesos atualizado:", self.pesos)

          else:
            print("\tsem erros")
        if qtde_erros == 0:
          # encerra o looping da epoca
          break

    def predict(self, x_test):

      np_x = x_test.values

      prediction = []
      for x in np_x:
        if self.pesos.dot(x) >= 0:
          prediction.append(1)
        else: 
          prediction.append(0)

      return prediction

# %%
df = pd.DataFrame([])

df["x1"] = [0.3, -0.6, -0.1, 0.1]
df["x2"] = [0.7, 0.3, -0.8, -0.45]

df["classe"] = [1, 0, 0, 1]

df
# Out:
#     x1    x2  classe
# 0  0.3  0.70       1
# 1 -0.6  0.30       0
# 2 -0.1 -0.80       0
# 3  0.1 -0.45       1

# %%
x_train = df[["x1", "x2"]]
y_train = df["classe"]

# %%
perceptron = Perceptron(taxa_aprendizado=0.5, n_features=x_train.shape[1])

# %%
perceptron.fit(x_train, y_train)
# Out:
# ---------------------------
# Epoca: 0
# 	---------------------------
# 	Amostra: 0
# 	x_atual: [0.3 0.7]
# 	pesos: [-0.601978   -0.17114957]
# 	output: -0.3003981003556664
# 	heaveside: 0
# 	erro: 1
# 	pesos atualizado: [-0.451978    0.17885043]
# 	---------------------------
# 	Amostra: 1
# 	x_atual: [-0.6  0.3]
# 	pesos: [-0.451978    0.17885043]
# 	output: 0.3248419298626519
# 	heaveside: 1
# 	erro: -1
# 	pesos atualizado: [-0.151978    0.02885043]
# 	---------------------------
# 	Amostra: 2
# 	x_atual: [-0.1 -0.8]
# 	pesos: [-0.151978    0.02885043]
# 	output: -0.007882542931884246
# 	heaveside: 0
# 	sem erros
# 	---------------------------
# 	Amostra: 3
# 	x_atual: [ 0.1  -0.45]
# 	pesos: [-0.151978    0.02885043]
# 	output: -0.02818049320879159
# 	heaveside: 0
# 	erro: 1
# 	pesos atualizado: [-0.101978   -0.19614957]
# ---------------------------
# Epoca: 1
# 	---------------------------
# 	Amostra: 0
# 	x_atual: [0.3 0.7]
# 	pesos: [-0.101978   -0.19614957]
# 	output: -0.16789810035566638
# 	heaveside: 0
# 	erro: 1
# 	pesos atualizado: [0.048022   0.15385043]
# 	---------------------------
# 	Amostra: 1
# 	x_atual: [-0.6  0.3]
# 	pesos: [0.048022   0.15385043]
# 	output: 0.017341929862651914
# 	heaveside: 1
# 	erro: -1
# 	pesos atualizado: [0.348022   0.00385043]
# 	---------------------------
# 	Amostra: 2
# 	x_atual: [-0.1 -0.8]
# 	pesos: [0.348022   0.00385043]
# 	output: -0.03788254293188423
# 	heaveside: 0
# 	sem erros
# 	---------------------------
# 	Amostra: 3
# 	x_atual: [ 0.1  -0.45]
# 	pesos: [0.348022   0.00385043]
# 	output: 0.033069506791208424
# 	heaveside: 1
# 	sem erros
# ---------------------------
# Epoca: 2
# 	---------------------------
# 	Amostra: 0
# 	x_atual: [0.3 0.7]
# 	pesos: [0.348022   0.00385043]
# 	output: 0.10710189964433359
# 	heaveside: 1
# 	sem erros
# 	---------------------------
# 	Amostra: 1
# 	x_atual: [-0.6  0.3]
# 	pesos: [0.348022   0.00385043]
# 	output: -0.20765807013734808
# 	heaveside: 0
# 	sem erros
# 	---------------------------
# 	Amostra: 2
# 	x_atual: [-0.1 -0.8]
# 	pesos: [0.348022   0.00385043]
# 	output: -0.03788254293188423
# 	heaveside: 0
# 	sem erros
# 	---------------------------
# 	Amostra: 3
# 	x_atual: [ 0.1  -0.45]
# 	pesos: [0.348022   0.00385043]
# 	output: 0.033069506791208424
# 	heaveside: 1
# 	sem erros

# %%
df_sample = df[["x1", "x2"]]
df
# Out:
#     x1    x2  classe
# 0  0.3  0.70       1
# 1 -0.6  0.30       0
# 2 -0.1 -0.80       0
# 3  0.1 -0.45       1

# %%
perceptron.predict(df_sample)
# Out:
# [1, 0, 0, 1]
